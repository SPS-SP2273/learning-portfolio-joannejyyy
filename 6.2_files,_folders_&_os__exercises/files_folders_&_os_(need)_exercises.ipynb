# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# # Task 1

# %%
m = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}
m['dec']
# Out:
# '12'

# %%
text = 'haha'
with open ('oct-08_singapore.txt', 'w') as file:
        file.write(text)
filename = 'oct-08_singapore.txt'
month = filename.split('-')[0]
day_country = filename.split('-')[1:]

number_months = m[months]
new = [number_months] + day_country
newname = "-".join(new)
print (newname)
# Out:
# 11-08_singapore.txt

# %% [markdown]
# # Task 2

# %%
def rename_my_file(filename): 
    #set the dictionary
    m = {
        'jan': '01', 'feb': '02', 'mar': '03',
        'apr': '04', 'may': '05', 'jun': '06',
        'jul': '07', 'aug': '08', 'sep': '09',
        'oct': '10', 'nov': '11', 'dec': '12'
    }
    months = filename.split('-')[0]
    day_country = filename.split('-')[1:]
    number_months = m[months]
    new = [number_months] + day_country
    newname = "-".join(new)

    return newname

# %% [markdown]
# # Task 3

# %%
test = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for oldname in test:
    newname = rename_my_file(oldname)
    print(oldname,'---->', newname)
# Out:
# oct-08_singapore.txt ----> 10-08_singapore.txt
# jul-10_cairo.txt ----> 07-10_cairo.txt
# may-15_dhaka.txt ----> 05-15_dhaka.txt
# may-13_cairo.txt ----> 05-13_cairo.txt
# oct-21_cairo.txt ----> 10-21_cairo.txt
# jan-10_singapore.txt ----> 01-10_singapore.txt
# jun-20_tokyo.txt ----> 06-20_tokyo.txt
# aug-06_jakarta.txt ----> 08-06_jakarta.txt
# dec-21_karachi.txt ----> 12-21_karachi.txt
# jan-01_tokyo.txt ----> 01-01_tokyo.txt

# %% [markdown]
# # Task 4

# %%
import glob

for path in glob.glob('data-file/*.txt'):
    folder, oldname = path.split('/', 1)
    newname = rename_my_file(oldname)
    newpath = "/".join([folder, newname])
    print(path,'---->', newpath)
    os.rename(path, newpath)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 5
#       3 for path in glob.glob('data-file/*.txt'):
#       4     folder, oldname = path.split('/', 1)
# ----> 5     newname = rename_my_file(oldname)
#       6     newpath = "/".join([folder, newname])
#       7     print(path,'---->', newpath)
#
# Cell In[38], line 11, in rename_my_file(filename)
#       9 months = filename.split('-')[0]
#      10 day_country = filename.split('-')[1:]
# ---> 11 number_months = m[months]
#      12 new = [number_months] + day_country
#      13 newname = "-".join(new)
#
# KeyError: '01'

# %% [markdown]
# # Task 5

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for city in cities:
   # print(city)
    os.mkdir(city)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[42], line 6
#       1 cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
#       2  'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
#       4 for city in cities:
#       5    # print(city)
# ----> 6     os.mkdir(city)
#
# FileExistsError: [Errno 17] File exists: 'Cairo'

# %% [markdown]
# # Task 6

# %%
def rename_my_file(filename): 
    #set the dictionary
    m = {
        'jan': '01', 'feb': '02', 'mar': '03',
        'apr': '04', 'may': '05', 'jun': '06',
        'jul': '07', 'aug': '08', 'sep': '09',
        'oct': '10', 'nov': '11', 'dec': '12'
    }
    months = filename.split('-')[0]
    day_country = filename.split('-')[1:]
    number_months = m[months]
    new = [number_months] + day_country
    newname = "-".join(new)

    return newname

# %%
glob.glob('data-file/*cairo.txt')

for filename in os.listdir('data-file'):
    if filename.endswith("cairo.txt"):
        current_path= os.path.join('data-file', filename)
        new_path = os.path.join('Cairo', filename)
        shutil.move(current_path, new_path)
        print(f"Moved: {filename}")

# %% [markdown]
# # Task 7

# %%
for filename in os.listdir('data-file'):
    if filename.endswith("dhaka.txt"):
        current_path= os.path.join('data-file', filename)
        new_path = os.path.join('Dhaka', filename)
        shutil.move(current_path, new_path)
        print(f"Moved: {filename}")

for filename in os.listdir('data-file'):
    if filename.endswith("jakarta.txt"):
        current_path= os.path.join('data-file', filename)
        new_path = os.path.join('Jakarta', filename)
        shutil.move(current_path, new_path)
        print(f"Moved: {filename}")

for filename in os.listdir('data-file'):
    if filename.endswith("karachi.txt"):
        current_path= os.path.join('data-file', filename)
        new_path = os.path.join('Karachi', filename)
        shutil.move(current_path, new_path)
        print(f"Moved: {filename}")

for filename in os.listdir('data-file'):
    if filename.endswith("cairo.txt"):
        current_path= os.path.join('data-file', filename)
        new_path = os.path.join('Cairo', filename)
        shutil.move(current_path, new_path)
        print(f"Moved: {filename}")
# Out:
# Moved: 06-09_dhaka.txt
# Moved: 08-14_dhaka.txt
# Moved: 06-28_dhaka.txt
# Moved: 11-18_dhaka.txt
# Moved: 11-20_dhaka.txt
# Moved: 07-16_dhaka.txt
# Moved: 07-02_dhaka.txt
# Moved: 06-04_dhaka.txt
# Moved: 08-19_dhaka.txt
# Moved: 05-26_dhaka.txt
# Moved: 12-16_dhaka.txt
# Moved: 07-23_dhaka.txt
# Moved: 04-20_dhaka.txt
# Moved: 11-15_dhaka.txt
# Moved: 06-25_dhaka.txt
# Moved: 11-01_dhaka.txt
# Moved: 12-02_dhaka.txt
# Moved: 10-07_dhaka.txt
# Moved: 10-18_dhaka.txt
# Moved: 07-28_dhaka.txt
# Moved: 12-09_dhaka.txt
# Moved: 08-27_dhaka.txt
# Moved: 12-28_dhaka.txt
# Moved: 08-06_dhaka.txt
# Moved: 07-09_dhaka.txt
# Moved: 06-23_dhaka.txt
# Moved: 02-20_dhaka.txt
# Moved: 11-07_dhaka.txt
# Moved: 10-01_dhaka.txt
# Moved: 12-04_dhaka.txt
# Moved: 07-10_dhaka.txt
# Moved: 05-15_dhaka.txt
# Moved: 05-01_dhaka.txt
# Moved: 09-19_dhaka.txt
# Moved: 06-02_dhaka.txt
# Moved: 02-01_dhaka.txt
# Moved: 04-19_dhaka.txt
# Moved: 08-20_dhaka.txt
# Moved: 08-18_dhaka.txt
# Moved: 06-05_dhaka.txt
# ...

# %%
for filename in os.listdir('data-file'):
    if filename.endswith("manila.txt"):
        current_path= os.path.join('data-file', filename)
        new_path = os.path.join('Manila', filename)
        shutil.move(current_path, new_path)
        print(f"Moved: {filename}")

for filename in os.listdir('data-file'):
    if filename.endswith("melbourne.txt"):
        current_path= os.path.join('data-file', filename)
        new_path = os.path.join('Melbourne', filename)
        shutil.move(current_path, new_path)
        print(f"Moved: {filename}")

for filename in os.listdir('data-file'):
    if filename.endswith("osaka.txt"):
        current_path= os.path.join('data-file', filename)
        new_path = os.path.join('Osaka', filename)
        shutil.move(current_path, new_path)
        print(f"Moved: {filename}")

for filename in os.listdir('data-file'):
    if filename.endswith("shanghai.txt"):
        current_path= os.path.join('data-file', filename)
        new_path = os.path.join('Shanghai', filename)
        shutil.move(current_path, new_path)
        print(f"Moved: {filename}")
# Out:
# Moved: 01-02_manila.txt
# Moved: 02-07_manila.txt
# Moved: 10-04_manila.txt
# Moved: 03-18_manila.txt
# Moved: 07-22_manila.txt
# Moved: 07-15_manila.txt
# Moved: 11-21_manila.txt
# Moved: 03-09_manila.txt
# Moved: 06-16_manila.txt
# Moved: 05-24_manila.txt
# Moved: 04-10_manila.txt
# Moved: 02-21_manila.txt
# Moved: 10-09_manila.txt
# Moved: 03-22_manila.txt
# Moved: 08-26_manila.txt
# Moved: 08-11_manila.txt
# Moved: 01-24_manila.txt
# Moved: 04-22_manila.txt
# Moved: 07-27_manila.txt
# Moved: 10-10_manila.txt
# Moved: 06-13_manila.txt
# Moved: 06-24_manila.txt
# Moved: 09-17_manila.txt
# Moved: 02-24_manila.txt
# Moved: 02-13_manila.txt
# Moved: 03-10_manila.txt
# Moved: 08-05_manila.txt
# Moved: 01-30_manila.txt
# Moved: 07-01_manila.txt
# Moved: 11-02_manila.txt
# Moved: 08-19_manila.txt
# Moved: 04-04_manila.txt
# Moved: 12-30_manila.txt
# Moved: 05-30_manila.txt
# Moved: 08-29_manila.txt
# Moved: 04-03_manila.txt
# Moved: 10-06_manila.txt
# Moved: 06-05_manila.txt
# ...

# %%
for filename in os.listdir('data-file'):
    if filename.endswith("singapore.txt"):
        current_path= os.path.join('data-file', filename)
        new_path = os.path.join('Singapore', filename)
        shutil.move(current_path, new_path)
        print(f"Moved: {filename}")

for filename in os.listdir('data-file'):
    if filename.endswith("tokyo.txt"):
        current_path= os.path.join('data-file', filename)
        new_path = os.path.join('Tokyo', filename)
        shutil.move(current_path, new_path)
        print(f"Moved: {filename}")
# Out:
# Moved: 06-23_singapore.txt
# Moved: 07-04_singapore.txt
# Moved: 02-24_singapore.txt
# Moved: 04-15_singapore.txt
# Moved: 02-20_singapore.txt
# Moved: 07-17_singapore.txt
# Moved: 06-09_singapore.txt
# Moved: 02-19_singapore.txt
# Moved: 10-06_singapore.txt
# Moved: 09-24_singapore.txt
# Moved: 10-11_singapore.txt
# Moved: 09-19_singapore.txt
# Moved: 12-23_singapore.txt
# Moved: 09-20_singapore.txt
# Moved: 11-25_singapore.txt
# Moved: 10-12_singapore.txt
# Moved: 10-05_singapore.txt
# Moved: 11-08_singapore.txt
# Moved: 10-01_singapore.txt
# Moved: 11-26_singapore.txt
# Moved: 09-23_singapore.txt
# Moved: 10-16_singapore.txt
# Moved: 02-27_singapore.txt
# Moved: 05-08_singapore.txt
# Moved: 07-07_singapore.txt
# Moved: 07-29_singapore.txt
# Moved: 04-01_singapore.txt
# Moved: 07-03_singapore.txt
# Moved: 07-14_singapore.txt
# Moved: 02-23_singapore.txt
# Moved: 04-05_singapore.txt
# Moved: 04-12_singapore.txt
# Moved: 04-21_singapore.txt
# Moved: 05-06_singapore.txt
# ...

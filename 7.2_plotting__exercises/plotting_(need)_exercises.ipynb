# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need) Exercises</span></div>

# %%
from matplotlib import pyplot as plt
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, 
             xerr= x_err, yerr= y_err, color= '#8B0000', 
             linestyle= '--', marker = 'o',
             markerfacecolor= 'yellow', 
             ecolor= 'black',capsize=5,
             label= 'Y values with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Exercise 2

# %%
import numpy as np 

x = np.linspace (0, 50, 10000)
sin_x = np.sin(x)
y = (np.e)**(-x/10) * sin_x

plt.plot (x, y)
plt.xlabel('X')
plt.ylabel('Y')
from IPython.display import display, Math, Latex
plt.title ("$e^{-x/10}sin x$")
plt.grid(alpha=.25)

# %%
import numpy as np 

x = np.linspace (0, 50, 10000)
sin_x = np.sin(x)
y = (np.e)**(-x/10) * sin_x

plt.plot (x, y)
plt.xlabel('X', colour = 'darkorange')
plt.ylabel('Y', colour = 'darkorange')
from IPython.display import display, Math, Latex
plt.title ("$e^{-x/10}sin x$")
plt.grid(alpha=.25)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 8
#       5 y = (np.e)**(-x/10) * sin_x
#       7 plt.plot (x, y)
# ----> 8 plt.xlabel('X', colour = 'darkorange')
#       9 plt.ylabel('Y', colour = 'darkorange')
#      10 from IPython.display import display, Math, Latex
#
# File ~/Documents/.venv/lib/python3.13/site-packages/matplotlib/pyplot.py:4407, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4398 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4399 def xlabel(
#    4400     xlabel: str,
#    (...)   4405     **kwargs,
#    4406 ) -> Text:
# -> 4407     return gca().set_xlabel(
#    4408         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4409     )
#
# File ~/Documents/.venv/lib/python3.13/site-packages/matplotlib/axes/_base.py:3645, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3638     x = {
#    3639         'left': 0,
#    3640         'center': 0.5,
#    3641         'right': 1,
#    3642     }[loc]
#    3643     kwargs.update(x=x, horizontalalignment=loc)
# -> 3645 return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#
# File ~/Documents/.venv/lib/python3.13/site-packages/matplotlib/axis.py:1902, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1900 if fontdict is not None:
#    1901     self.label.update(fontdict)
# -> 1902 self.label.update(kwargs)
#    1903 self.stale = True
#    1904 return self.label
#
# File ~/Documents/.venv/lib/python3.13/site-packages/matplotlib/text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File ~/Documents/.venv/lib/python3.13/site-packages/matplotlib/artist.py:1223, in Artist.update(self, props)
#    1215 def update(self, props):
#    1216     """
#    1217     Update this artist's properties from the dict *props*.
#    1218
#    (...)   1221     props : dict
#    1222     """
# -> 1223     return self._update_props(
#    1224         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File ~/Documents/.venv/lib/python3.13/site-packages/matplotlib/artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: 'Text' object has no property 'colour'
